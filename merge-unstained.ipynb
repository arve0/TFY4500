# %%
# %pylab inline
from glob import glob
from matrixscreener import Experiment
from tifffile import imread, imsave, imshow

folders = glob('/Users/arve/Dokumenter/TFY4500/unstained/experiment--*')

experiments = []
for f in folders:
    experiments.append(Experiment(f))
    print(f + ' loaded')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/arve/Dokumenter/TFY4500/unstained/experiment--row 0-2 loaded
# ...
# /Users/arve/Dokumenter/TFY4500/unstained/experiment--row 3-5 loaded

# %%
files = []
for experiment in experiments:
    files.extend(experiment.stitch())
imshow(imread(files[0]))
# Out:
# (<matplotlib.figure.Figure at 0x10cb7c978>,
# ...
#  <matplotlib.image.AxesImage at 0x10f8dc8d0>)
