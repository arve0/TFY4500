# %%
# %run common.ipynb
import cv2
img = ndimage.imread('hyd-stopp.tif')
histshow(img)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-7345bb3f9938> in <module>()
#       1 get_ipython().magic(u'run common.ipynb')
# ----> 2 import cv2
#       3 img = ndimage.imread('hyd-stopp.tif')
#       4 histshow(img)
#
# ImportError: No module named cv2

# %%
print img.max()
print img.shape
gimshow(img)
# Out:
# 255
# (1921, 1937)
