# %%
# %run ../common.ipynb
import sys
sys.path.append('..')
from tifffile import imread, imsave, imshow
img = imread('hyd-stopp.tif')
for i in img:
    histshow(i)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['imshow', 'imread', 'imsave']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
for i in img:
    imshow(i)

# %%
for i, image in enumerate(img.pages()):
    hist[i] = np.bincount(image.flatten())
hist[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-c0dfdd77bd2c> in <module>()
# ----> 1 for i, image in enumerate(img.pages()):
#       2     hist[i] = np.bincount(image.flatten())
#       3 hist[0]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'pages'
